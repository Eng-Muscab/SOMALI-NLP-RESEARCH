# %% [markdown]
# # STEP 8 - AfriBERTa Fine-tuning
#
# Notebook-kan wuxuu ordayaa AfriBERTa fine-tuning (`castorini/afriberta_base`) adoo adeegsanaya script-ka Step 8.

# %%
# Ka orod repo root
# !python models/transformers/step8_finetune_transformers.py --model afriberta
