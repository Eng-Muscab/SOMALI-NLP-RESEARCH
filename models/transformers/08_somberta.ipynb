# %% [markdown]
# # STEP 8 - SomBERTa Fine-tuning
#
# Notebook-kan wuxuu ordayaa SomBERTa fine-tuning (`shuabdaud/SomBERTa`) adoo adeegsanaya script-ka Step 8.

# %%
# Ka orod repo root
# !python models/transformers/step8_finetune_transformers.py --model somberta --trust-remote-code
