# %% [markdown]
# # STEP 8 - mBERT Fine-tuning
#
# Notebook-kan wuxuu ordayaa mBERT fine-tuning (`bert-base-multilingual-cased`) adoo adeegsanaya script-ka Step 8.

# %%
# Ka orod repo root
# !python models/transformers/step8_finetune_transformers.py --model mbert
