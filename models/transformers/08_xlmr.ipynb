# %% [markdown]
# # STEP 8 - XLM-RoBERTa Fine-tuning
#
# Notebook-kan wuxuu ordayaa XLM-R fine-tuning (`xlm-roberta-base`) adoo adeegsanaya script-ka Step 8.

# %%
# Ka orod repo root
# !python models/transformers/step8_finetune_transformers.py --model xlmr
